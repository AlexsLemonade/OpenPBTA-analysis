# %%
library(ggplot2)
library(repr)
dat <- read.table("../../scratch/somatic-count_with-histologies.tsv", sep = "\t")
names(dat) <- c('sample','mutation','project','caller','tumor_type')

# %%
options(repr.plot.width=12, repr.plot.height=6)
ggplot(dat, aes(reorder(tumor_type, mutation, FUN = median), mutation, color=project)) + 
geom_boxplot() + ylim(0, 200) + theme(axis.text.x = element_text(angle = 45, hjust = 1)) + 
facet_grid(rows=vars(caller))
# Out:
# Warning message:
# “Removed 39 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
options(repr.plot.width=12, repr.plot.height=4)
ggplot(
    subset(dat, caller=="lancet"), 
    aes(reorder(tumor_type, mutation, FUN = median), 
    mutation, color=project
)) + geom_boxplot() + ylim(0, 200) + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# Warning message:
# “Removed 17 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
ggplot(
    subset(dat, caller=="mutect2"), 
    aes(reorder(tumor_type, mutation, FUN = median), 
    mutation, color=project
)) + geom_boxplot() + ylim(0, 200) + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# Warning message:
# “Removed 8 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
ggplot(
    subset(dat, caller=="strelka2"), 
    aes(reorder(tumor_type, mutation, FUN = median), 
    mutation, color=project
)) + geom_boxplot() + ylim(0, 200) + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# Warning message:
# “Removed 14 rows containing non-finite values (stat_boxplot).”
# plot without title
